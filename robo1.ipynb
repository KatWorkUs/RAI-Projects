# %%
import stable_baselines3
print(stable_baselines3.__version__)
# Out:
# 2.7.0

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import time
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
env = gym.make("CartPole-v1", render_mode="human")
env = Monitor(env)  

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=5000, progress_bar=True)
print("Training complete!\n")

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Average reward over 10 eval episodes: {mean_reward:.2f} ± {std_reward:.2f}")

obs, _ = env.reset()
for step in range(1000):
    action, _ = model.predict(obs)
    obs, reward, done, trunc, info = env.step(action)
    if done or trunc:
        obs, _ = env.reset()
env.close()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | 25.6     |
# | time/              |          |
# |    fps             | 45       |
# |    iterations      | 1        |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29           |
# |    ep_rew_mean          | 29           |
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 2            |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0090983175 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.00613     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.45         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0202      |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.7       |
# |    ep_rew_mean          | 40.7       |
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 3          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00958886 |
# |    clip_fraction        | 0.0604     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.663     |
# |    explained_variance   | 0.0764     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.4       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0173    |
# |    value_loss           | 39.7       |
# ----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training complete!
#
# Average reward over 10 eval episodes: 332.40 ± 167.43
